# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
data = [
    "The car stopped at the red light",
    "I love driving on the open road",
    "She bought a new car last month",
    "The engine makes a loud noise",
    "He is fixing the car in the garage",
    "The tires need to be replaced soon",
    "The car broke down on the highway",
    "The dashboard lights are flashing",
    "The SUV has plenty of cargo space",
    "The car runs on electric power", 
    "She accelerated as the light turned green", 
    "The new model comes with a sunroof", 
    "He parked the car in the shade", 
    "The car wash made the car shine", 
    "The sedan is more fuel-efficient", 
    "The sports car zoomed past us", 
    "The car's battery died overnight", 
    "The mechanic checked the oil level", 
    "He cleaned the windshield thoroughly", 
    "The car needs a full tank of gas", 
    "The car alarm went off suddenly", 
    "They test-drove the hybrid car", 
    "She prefers automatic transmission", 
    "The convertible top is down", 
    "The rearview mirror needs adjusting", 
    "The car stereo plays music loudly", 
    "The headlights are bright at night", 
    "The car has four-wheel drive", 
    "He installed a new exhaust system", 
    "The car key has a remote control", 
    "The steering wheel is smooth to handle", 
    "The wipers cleared the rain off", 
    "The speedometer shows the car's speed", 
    "The air conditioner cools the car quickly", 
    "The car's paint is scratched", 
    "He leased the car for three years", 
    "The car has heated seats", 
    "The side mirrors fold automatically", 
    "The trunk is full of groceries", 
    "The car's suspension feels soft", 
    "She reversed the car into the driveway", 
    "The license plate is new", 
    "The engine roars when started", 
    "The car stalled at the intersection", 
    "He pressed the brake pedal", 
    "The road trip took hours", 
    "The driver adjusted the seat", 
    "The car has a GPS navigation system", 
    "The headlights need to be replaced", 
    "The compact car is easy to park", 
    "She signaled before turning left", 
    "The car's windshield cracked", 
    "The tires have excellent grip", 
    "The rear seat folds down for more space", 
    "The car is due for maintenance", 
    "The carpool lane was empty", 
    "The car interior smells like new", 
    "He upgraded to a luxury car", 
    "The road was slippery from the rain", 
    "The dashboard displays the fuel level", 
    "The new car has a sleek design", 
    "The car door is hard to open", 
    "The hybrid car is energy-efficient", 
    "The car was towed to the repair shop", 
    "The mechanic rotated the tires", 
    "The car's odometer shows high mileage", 
    "The backseat has child safety locks", 
    "The car is equipped with airbags", 
    "The sunroof lets in natural light", 
    "He filled the car with premium fuel", 
    "The windows are tinted", 
    "The car has a manual transmission", 
    "The car horn honked loudly", 
    "The rear bumper is dented", 
    "The car has an all-wheel-drive system", 
    "The traffic was heavy", 
    "The car handles curves smoothly", 
    "She replaced the windshield wipers", 
    "The car's brakes squeak", 
    "The headlights are foggy", 
    "He added oil to the engine", 
    "The car is parked in the garage", 
    "The fuel pump was replaced", 
    "The airbag deployed during the crash", 
    "The leather seats are comfortable", 
    "The car rental agency is nearby", 
    "The car started after a jump-start", 
    "She drove the car to the mountains", 
    "The speed limit is posted on the sign", 
    "He installed new spark plugs", 
    "The exhaust pipe is rusted", 
    "The car stereo has Bluetooth connectivity", 
    "The backseat is spacious", 
    "The electric car is silent", 
    "The car has rear parking sensors", 
    "He cleaned the car windows", 
    "The tires are overinflated", 
    "The car accelerated quickly", 
    "The steering is responsive", 
    "The muffler needs to be repaired", 
    "The car's engine overheated", 
    "She loves the smell of new cars", 
    "The tire pressure is low", 
    "The engine oil needs to be changed", 
    "The car came with a full warranty", 
    "The headlights are turned off automatically", 
    "The new car has a wireless charger", 
    "He washed the car by hand", 
    "The brakes were replaced last week", 
    "The car's air filter was dirty", 
    "The car's transmission is slipping", 
    "The rear window was shattered", 
    "The license plate was stolen", 
    "The car stopped.",
    "She drives fast.",
    "He fixed it.",
    "The tires squeaked.",
    "Fuel is low.",
    "They test drove.",
    "The engine roared.",
    "The car shined.",
    "It needs gas.",
    "He parked outside.",
    "The road curved.",
    "She sped up.",
    "The lights flashed.",
    "Wipers are on.",
    "The car beeped.",
    "He pressed start.",
    "She slowed down.",
    "The door opened.",
    "The seats folded.",
    "Windows are tinted.",
    "The battery died.",
    "It runs well.",
    "The car accelerated.",
    "He drove slowly.",
    "The car is quiet.",
    "The exhaust rumbled.",
    "He cleaned it.",
    "The SUV stalled.",
    "The brakes squeak.",
    "The trunk opened.",
    "The car drifted.",
    "She signaled left.",
    "He honked twice.",
    "The headlights dimmed.",
    "She turned right.",
    "It was fast.",
    "It rained lightly.",
    "She loves driving.",
    "The fuel gauge blinked.",
    "He replaced tires.",
    "They checked oil.",
    "The engine hummed.",
    "The car sputtered.",
    "She drove home.",
    "He washed it.",
    "The stereo played.",
    "The wheel spun.",
    "The hood opened.",
    "It overheated yesterday.",
    "The engine stalled.",
    "The car's suspension was too stiff", 
    "The car hit a pothole", 
    "The car has a backup camera", 
    "She test-drove the electric vehicle", 
    "The car's headlights are dim", 
    "The radio is playing her favorite song", 
    "He added coolant to the radiator", 
    "The car is running smoothly", 
    "The trunk won't close properly", 
    "The windshield has frost on it", 
    "The hybrid car saves on fuel", 
    "The engine check light is on", 
    "The backseat is full of boxes", 
    "The car's tires are worn out", 
    "The car manual is in the glove compartment", 
    "She turned off the engine", 
    "He checked the tire pressure", 
    "The air conditioning isn't working", 
    "The car horn is broken", 
    "The convertible's roof is stuck", 
    "The steering wheel cover is worn out", 
    "The car windows fogged up", 
    "The car's stereo has surround sound", 
    "The SUV is great for off-roading", 
    "The sedan is more affordable", 
    "The luxury car has leather seats", 
    "The car doors locked automatically", 
    "The exhaust makes a loud rumble", 
    "The windshield was covered in bugs", 
    "The car battery needs to be replaced", 
    "The driver slammed on the brakes", 
    "The engine revved as he accelerated", 
    "The gas station is a few miles away", 
    "The car was covered in snow", 
    "The car's interior is black leather", 
    "The front bumper has a crack", 
    "The road was bumpy", 
    "The car handles well in the snow", 
    "He changed the car's air filter", 
    "The headlight bulbs were replaced", 
    "The car stereo has a CD player", 
    "The rearview camera is blurry", 
    "The car's trunk is spacious", 
    "The driver's seat is adjustable", 
    "The car's tires were rotated", 
    "She opened the sunroof", 
    "He checked the oil level", 
    "The car's airbag was faulty", 
    "The fuel gauge reads empty", 
    "The car has a turbocharged engine", 
    "The interior lighting is soft", 
    "The car door handle is loose", 
    "The car's navigation system is outdated", 
    "The tail lights are broken", 
    "The car's battery is low", 
    "He replaced the car's brake pads", 
    "The car wash left water spots", 
    "The driver honked the horn", 
    "The engine stalled at a stoplight", 
    "The car's interior lights flickered", 
    "The car alarm was disabled", 
    "The car needs new tires", 
    "The rear window tint is peeling",
    "The car's headlights were dim during the storm",
    "The driver adjusted the rearview mirror before starting",
    "The electric car has a long battery range",
    "He polished the car until it shone",
    "The fuel economy of this car is impressive",
    "The car's infotainment system supports voice commands",
    "The new tires provide better traction on wet roads",
    "The automatic wipers activated as soon as it started raining",
    "She noticed a strange sound coming from the engine",
    "The rear spoiler adds sporty look to the car",
    "The heated steering wheel is great for winter driving",
    "The dashboard indicates the tire pressure is low",
    "He booked an appointment for an oil change",
    "The car's GPS system recalculated the route",
    "She adjusted the seatbelt for a comfortable fit",
    "The driver activated cruise control on the highway",
    "The side airbags deployed during the accident",
    "The driver switched to eco mode for better fuel efficiency",
    "The car's sun visors help block the glare",
    "The hybrid car recharges its battery while braking",
    "He installed new performance tires for better handling",
    "The luxury SUV has a panoramic sunroof",
    "The car's navigation system provides real-time traffic updates",
    "The backup camera helps when reversing into tight spaces",
    "The car's digital speedometer is easy to read",
    "The trunk space is large enough to fit multiple suitcases",
    "The sound system in the car delivers crystal-clear audio",
    "He installed a roof rack to carry extra luggage",
    "The all-season tires work well in both summer and winter",
    "The car's seat warmers were a nice feature on a cold morning",
    "The driver activated the lane-keeping assist feature",
    "The parking sensors beeped as the car approached an object",
    "The rear-seat entertainment system kept the kids occupied",
    "The driver used the paddle shifters for a more sporty feel",
    "The heads-up display shows speed and navigation information",
    "The car's keyless entry system is very convenient",
    "She connected her phone to the car's Bluetooth system",
    "The adaptive headlights turn with the steering wheel",
    "The regenerative braking system helps extend the electric range",
    "The built-in dashcam recorded the entire road trip",
    "He installed undercarriage lighting for a custom look",
    "The car's adaptive suspension adjusts for a smoother ride",
    "The driver enabled the sport mode for a more dynamic drive",
    "The cooled seats are perfect for hot summer days",
    "She upgraded the car with custom alloy wheels",
    "The car's emergency braking system prevented a collision",
    "The retractable side mirrors fold in automatically when parked",
    "The driver used the automatic parallel parking feature",
    "The rain-sensing wipers activated when it started to drizzle",
    "The driver set the car's speed limiter for city driving",
    "The rear cross-traffic alert system prevented a collision",
    "The car's panoramic roof provides a great view of the sky",
    "The digital climate control adjusts the temperature automatically",
    "The car's wireless charging pad is very convenient",
    "The rear air vents keep the backseat passengers comfortable",
    "He installed a custom exhaust for a louder engine sound",
    "The auto-dimming rearview mirror helps reduce glare at night",
    "The car's proximity sensors detect nearby obstacles",
    "She appreciated the heated side mirrors on frosty mornings",
    "The vehicle's blind-spot monitoring system is a great safety feature",
    "The leather upholstery gives the interior a premium feel",
    "The driver's seat has a memory function for multiple drivers",
    "The car's power tailgate can be opened hands-free",
    "The heads-up display projects navigation directions onto the windshield",
    "The built-in navigation system updates maps automatically",
    "He connected his phone to the car's USB port for charging",
    "The car's voice control system responds to commands accurately",
    "The rear sunshade provides extra comfort for backseat passengers",
    "The digital key allows unlocking the car using a smartphone",
    "The car's air quality sensor adjusts the ventilation automatically",
    "The rear fog lights improve visibility in bad weather",
    "The driver's seat offers lumbar support for long trips",
    "The wireless Apple CarPlay is a great feature for iPhone users",
    "The car's emergency SOS button can call for help in an accident",
    "The remote start feature is useful on cold mornings",
    "The driver activated the pedestrian detection system",
    "The ambient interior lighting creates a relaxing atmosphere",
    "The car's built-in Wi-Fi hotspot allows internet access on the go",
    "The adaptive cruise control maintains a set distance from the car ahead",
    "The vehicle's night vision system enhances visibility in the dark",
    "The car's tire pressure monitoring system provides real-time alerts",
    "The car's glass roof provides a sense of openness",
    "The surround-view camera makes parking in tight spots easy",
    "The automatic high beams adjust based on traffic conditions",
    "The car's steering wheel has audio controls for convenience",
    "The headrests are adjustable for added comfort",
    "The car's cooled glovebox keeps drinks chilled",
    "The rain-repellent windows improve visibility during storms",
    "The driver switched between driving modes for different terrains",
    "The 360-degree camera provides a bird's-eye view of the car",
    "The driver used the hands-free voice assistant to make a call"
]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(oov_token='random')

# %%
tokenizer.fit_on_texts(data)

# %%
# Indexing of words
tokenizer.word_index
# Out:
# {'random': 1,
#  'the': 2,
#  'car': 3,
#  'is': 4,
#  "car's": 5,
#  'a': 6,
#  'he': 7,
#  'for': 8,
#  'she': 9,
#  'to': 10,
#  'has': 11,
#  'system': 12,
#  'in': 13,
#  'on': 14,
#  'engine': 15,
#  'was': 16,
#  'are': 17,
#  'driver': 18,
#  'new': 19,
#  'tires': 20,
#  'it': 21,
#  'rear': 22,
#  'fuel': 23,
#  'replaced': 24,
#  'of': 25,
#  'headlights': 26,
#  'wheel': 27,
#  'needs': 28,
#  'automatically': 29,
#  'seat': 30,
#  'road': 31,
#  'be': 32,
#  'with': 33,
#  'battery': 34,
#  'oil': 35,
#  'windshield': 36,
#  'drove': 37,
#  'installed': 38,
#  'steering': 39,
#  'air': 40,
#  'navigation': 41,
#  'interior': 42,
#  'provides': 43,
#  'feature': 44,
#  'at': 45,
#  'driving': 46,
#  'lights': 47,
#  'electric': 48,
#  'as': 49,
#  'more': 50,
#  'off': 51,
#  'stereo': 52,
#  'exhaust': 53,
#  'control': 54,
#  'wipers': 55,
#  'seats': 56,
#  'trunk': 57,
#  'backseat': 58,
#  'windows': 59,
#  'an': 60,
#  'were': 61,
#  'opened': 62,
#  'camera': 63,
# ...

# %%
# Words with their frequency
tokenizer.word_counts
# Out:
# OrderedDict([('the', 337),
#              ('car', 83),
#              ('stopped', 2),
#              ('at', 5),
#              ('red', 1),
#              ('light', 4),
#              ('i', 1),
#              ('love', 1),
#              ('driving', 5),
#              ('on', 16),
#              ('open', 2),
#              ('road', 6),
#              ('she', 23),
#              ('bought', 1),
#              ('a', 47),
#              ('new', 12),
#              ('last', 2),
#              ('month', 1),
#              ('engine', 15),
#              ('makes', 3),
#              ('loud', 2),
#              ('noise', 1),
#              ('he', 33),
#              ('is', 54),
#              ('fixing', 1),
#              ('in', 18),
#              ('garage', 2),
#              ('tires', 12),
#              ('need', 2),
#              ('to', 23),
#              ('be', 6),
#              ('replaced', 9),
#              ('soon', 2),
#              ('broke', 1),
#              ('down', 4),
# ...

# %%
# No of sentences
tokenizer.document_count
# Out:
# 317

# %%
sequences = tokenizer.texts_to_sequences(data)

# %%
sequences
# Words will be displayed as indexes
# Out:
# [[2, 3, 139, 45, 2, 260, 66],
#  [261, 262, 46, 14, 2, 140, 31],
#  [9, 263, 6, 19, 3, 141, 264],
#  [2, 15, 95, 6, 142, 265],
#  [7, 4, 266, 2, 3, 13, 2, 143],
#  [2, 20, 144, 10, 32, 24, 145],
#  [2, 3, 267, 67, 14, 2, 146],
#  [2, 96, 47, 17, 268],
#  [2, 68, 11, 269, 25, 270, 97],
#  [2, 3, 147, 14, 48, 148],
#  [9, 69, 49, 2, 66, 70, 271],
#  [2, 19, 272, 273, 33, 6, 71],
#  [7, 72, 2, 3, 13, 2, 274],
#  [2, 3, 149, 275, 2, 3, 276],
#  [2, 150, 4, 50, 23, 151],
#  [2, 277, 3, 278, 279, 280],
#  [2, 5, 34, 152, 281],
#  [2, 153, 73, 2, 35, 98],
#  [7, 99, 2, 36, 282],
#  [2, 3, 28, 6, 74, 283, 25, 100],
#  [2, 3, 154, 284, 51, 285],
#  [101, 102, 37, 2, 75, 3],
#  [9, 286, 76, 103],
#  [2, 287, 288, 4, 67],
#  [2, 77, 104, 28, 289],
#  [2, 3, 52, 290, 291, 155],
#  [2, 26, 17, 292, 45, 105],
#  [2, 3, 11, 293, 27, 106],
#  [7, 38, 6, 19, 53, 12],
#  [2, 3, 156, 11, 6, 157, 54],
#  [2, 39, 27, 4, 294, 10, 158],
#  [2, 55, 295, 2, 78, 51],
#  [2, 159, 107, 2, 5, 79],
# ...

# %%
# Applying Padding
from keras.utils import pad_sequences

# %%
sequences = pad_sequences(sequences, padding = 'post')  # Will add 0's at Last due to post.

# %%
sequences
# Out:
# array([[  2,   3, 139, ...,   0,   0,   0],
#        [261, 262,  46, ...,   0,   0,   0],
#        [  9, 263,   6, ...,   0,   0,   0],
#        ...,
#        [  2,  18, 221, ...,   0,   0,   0],
#        [  2, 653, 654, ...,   2,   3,   0],
#        [  2,  18, 132, ...,   6, 259,   0]])

# %% [markdown]
# **Input data is prepared**
